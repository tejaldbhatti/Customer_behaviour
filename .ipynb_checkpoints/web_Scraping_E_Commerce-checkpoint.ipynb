# %%
import pandas as pd
import numpy as np
import time
import string
import re
import requests
from bs4 import BeautifulSoup
import selenium
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
# Out:
# C:\Users\Denish\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
#Aliexpress get all source code
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)
driver.get('https://www.aliexpress.com/category/100003109/women-clothing.html')
time.sleep(5)
soup=driver.page_source
driver.quit()
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

# Loading the webpage
driver.get('https://www.aliexpress.com/category/100003109/women-clothing.html')
time.sleep(5)

# Parsing the page source using BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')soup

# %%
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

# Loading the webpage
driver.get('https://www.aliexpress.com/category/100003109/women-clothing.html')
time.sleep(5)

# Get the page source
page_source = driver.page_source

# Parsing the page source using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Find all <div> elements with the specified class
div_elements = soup.find_all('div', class_="multi--dealContainer--T8SnTim")

# Loop through the found <div> elements
for div in div_elements:
    # Extract the data or perform operations on each <div> element
    print(div.text.strip())

# Quitting the WebDriver
driver.quit()

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ebay.de/sch/i.html?_from=R40&_trksid=p4432023.m570.l1313&_nkw=scooter&_sacat=0'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all the product titles
product_titles = soup.find_all('div',class_='s-item__title')
title =[]
for div in product_titles:
    # Extract the data or perform operations on each <div> element
    title.append(div.span.text.strip()) 
    

product_prices = soup.find_all('span', class_='s-item__price')
price =[]
for i in product_prices:
    price.append(i.text.strip()) 
    
    
product_feature = soup.find_all('span', class_='s-item__dynamic s-item__coupon')
feature = []
for i1 in product_feature:
    feature.append(i1.text.strip())    
    
seller_info =[]    
product_seller = soup.find_all('span', class_='s-item__seller-info-text')
for i2 in product_seller:
    seller_info.append(i2.text.strip())

# %%
data_scooter = list(zip(title, price,seller_info))

# %%
data_scooter
# Out:
# [('Shop on eBay', '$20.00', 'mg-scooter (285) 97,6%'),
#  ('Urban E-Scooter mit Straßenzulassung Elektroroller Faltbar Elektro City Roller',
#   'EUR 359,00',
#   'mg-scooter (285) 97,6%'),
#  ('10 Zoll E-Scooter KickScooter mit Straßenzulassung 350 W Elektroroller E Roller',
#   'EUR 359,00',
#   'mg-scooter (285) 97,6%'),
#  ('Elektroroller Mit Straßenzulassung Elektro Scooter 10 Zoll 7800mAh E-Scooter ABE',
#   'EUR 359,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Chilli Pro Reaper Stunt-scooter H=84cm Trick Park Roller + Griptape Wave Blau',
#   'EUR 179,00',
#   'weroll_tech (421) 98,9%'),
#  ('E-Scooter mit Straßenzulassung 13Ah 624Wh 500W Offroad Elektroroller Joyor S5',
#   'EUR 649,00',
#   'leqi-official_store (283) 98,6%'),
#  ('A11 E-Scooter mit Straßenzulassung, Faltbarer Elektroroller Bis 30km Gebraucht',
#   'EUR 269,00',
#   'evemotiongmbh (75.588) 97,1%'),
#  ('E-Scooter mit Straßenzulassung Elektroroller ABE Faltbar Escooter Elektro Roller',
#   'EUR 799,00',
#   'mg-scooter (285) 97,6%'),
#  ('Megawheels Faltbarer E-Scooter Elektroroller 25km 5200mAH Elektro Scooter',
#   'EUR 299,00',
#   'jan_shop (22.256) 98,9%'),
#  ('LED Kinderroller Kinderscooter Cityroller Dreiradscooter Scooter Kinder Ricokids',
#   'EUR 42,99',
#   'jan_shop (22.256) 98,9%'),
#  ('LED Kinderroller Kinderscooter Cityroller Dreiradscooter Scooter Kinder Ricokids',
#   'EUR 37,99',
#   'jan_shop (22.256) 98,9%'),
#  ('LED Kinderroller Kinderscooter Cityroller Dreiradscooter Scooter Kinder Ricokids',
#   'EUR 42,99',
#   'calimpx (7.498) 99,2%'),
#  ('Kinderroller Tretroller Cityroller Geschenk Höhenverstellbar Scooter Klappbar',
#   'EUR 36,99',
#   'jan_shop (22.256) 98,9%'),
#  ('Stunt Scooter Roller SOKE ABEC9 Kickscooter Kinderroller Tretroller PERFECT GIFT',
#   'EUR 54,99',
#   'chengdukangten-5 (2.153) 99,1%'),
#  ('Erwachsene Elektroroller+Handbremse Elektro Scooter Faltbar E-scooter Schwarz',
#   'EUR 72,00',
#   'intheafterglow (1.937) 99%'),
#  ('Scooter Roller Kinderroller Kickscooter Cityroller Erwachsene Kinder Tretroller',
#   'EUR 50,99',
#   'jan_shop (22.256) 98,9%'),
#  ('Stunt Scooter SOKE GO! Cityroller Kickscooter Kinderroller Tretroller Funscooter',
#   'EUR 38,99',
#   'juskys24 (83.844) 98,5%'),
#  ('Cityroller Kinderroller Scooter Roller Tretroller Kickroller Stahl PU ArtSport®',
#   'EUR 37,99 bis EUR 44,99',
#   'mediamarkt (1.298.806) 98,5%'),
#  ('NINEBOT F2 PRO D E-Scooter (10 Zoll, Black)',
#   'EUR 599,99',
#   'technische_accessoires (32.577) 99,9%'),
#  ('Denver Elektro Roller SEL-65230B Black E- Scooter 300W 12km 20km/h schwarz',
#   'EUR 169,95',
#   'michaelha36 (1.182) 97,8%'),
#  ('Kinder Roller Scooter Cityroller 2 Big LEDRäder Höheverstellbare Jungen Mädchen',
#   'EUR 29,99',
#   'mg-scooter (285) 97,6%'),
#  ('8 Zoll Elektroroller E-Roller 36V 5200mAh E-Scooter 25km/h Erwachsene Scooter DE',
#   'EUR 229,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('MGP Madd Gear MGX Extreme Stunt-Scooter H=90cm Roller Leicht Rainbow neochrome',
#   'EUR 369,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('MGP Madd Gear MGX Team Stunt-Scooter H=86,5cm Trick Tret Roller butanol Silber',
#   'EUR 249,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Blunt Prodigy S9 Komplett Trick Tret Roller Stunt-Scooter H=86cm Park galaxy',
#   'EUR 229,90',
#   'rolf-steiner (989) 100%'),
#  ('Muuwmi Scooter Trettroller Cityroller Big Wheel 205 Speed Formula',
#   'EUR 19,99',
#   'avmea-de (2.678) 98%'),
#  ('Kinderroller bis 100KG Kinder Scooter 2-Räder Jungen Hinterbremsen Cityroller',
#   'EUR 36,99',
#   'saturn (1.079.025) 97,6%'),
#  ('NINEBOT KickScooter MAX G2D powered by Segway E-Scooter (10 Zoll, Schwarz)',
#   'EUR 829,99',
#   'intergo-de (341) 100%'),
#  ('Hoverboard Kinder 6,5 Zoll Elektro Scooter Elektroroller Bluetooth LED Segway-DE',
#   'EUR 98,99 bis EUR 119,99',
#   'access2net.gmbh (1.314) 100%'),
#  ('E-Scooter mit Straßenzulassung KSR ESA 800 Grundig ERG02',
#   'EUR 199,00',
#   'mediamarkt (1.298.806) 98,5%'),
#  ('XIAOMI Electric Scooter 4 Lite E-Scooter (8,5 Zoll, Black)',
#   'EUR 429,99',
#   'weroll_tech (421) 98,9%'),
#  ('E-Scooter mit Straßenzulassung 10 Zoll 500W Offroad Elektroroller Federung Y8-S',
#   'EUR 899,00',
#   'smallbug_technikshop (166.855) 99,6%'),
#  ('Denver Elektro Kinder Tretroller SCK-5400 Schwarz Scooter bis zu 50 kg',
#   'EUR 69,10',
#   'avmea-de (2.678) 98%'),
#  ('Kinderroller bis 50KG 3-in-1 Kinderscooter meteor LED Räder Scooter Cityroller',
#   'EUR 32,99 bis EUR 34,99',
#   'innovation-store (90.253) 97,3%'),
#  ('FORÇA C-PRO Elektro-Scooter 50 km/h ElektroRoller E-Scooter STRASSENZULASSUNG',
#   'EUR 399,99',
#   'mg-scooter (285) 97,6%'),
#  ('Elektroroller Elektro Scooter 350W mit APP E-Scooter bis 30km Reichweite 9 Zoll',
#   'EUR 349,00',
#   'iscooter_global (363) 96,5%'),
#  ('Elektro Roller 500W mit Straßenzulassung ABE E-Scooter bis 120kg 40km Max.10Zoll',
#   'EUR 409,99',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Bewegt Kleinkinder Stunt-Scooter Tret-Roller H=74cm Neochrom Rainbow Regenbogen',
#   'EUR 139,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Fuzion 2022 Z350 Street Stunt-Scooter Trick-Tret-Roller Boxed H=92cm Schwarz',
#   'EUR 199,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Anaquda Cobra Stunt-Scooter H=85cm Kinder Trick Park Tret Roller Schwarz ROT',
#   'EUR 149,90',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Chilli Pro Archie Cole Stunt-Scooter Tretroller Trick H=86,5cm schwarz',
#   'EUR 224,90',
#   'jan_shop (22.256) 98,9%'),
#  ('Stunt Scooter Roller SOKE ABEC9 Kickscooter Kinderroller Tretroller PERFECT GIFT',
#   'EUR 46,90 bis EUR 54,99',
#   'wmk-shop24 (315.099) 97,6%'),
#  ('KESSER® Cityroller Kinderroller Scooter Roller Tretroller Kickroller Kickscooter',
#   'EUR 49,80',
#   'remoni-1619 (342) 98,6%'),
#  ('EVERCROSS EV10Z 10"E-Scooter mit Straßenzulassung(ABE),Hinter Motor 350W,11.4AW.',
#   'EUR 399,00',
#   'novendu (72.497) 99,7%'),
#  ('Xiaomi Mi Electric scooter 1S black E-Scooter Straßenzulassung - GUTER ZUSTAND!!',
#   'EUR 333,00',
#   'arebos-shop (436.919) 97,9%'),
#  ('AREBOS Tretroller Kickroller Cityroller Kinderroller Erwachsene Scooter Pink',
#   'EUR 39,90',
#   'novendu (72.497) 99,7%'),
#  ('VMAX VX2 Pro LT-B schwarz E-Scooter Straßenzulassung - GEBRAUCHT - DE HÄNDLER!',
#   'EUR 499,00',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Striker Lux Stunt-Scooter H=87cm 3,1kg Blau Chrome',
#   'EUR 210,99',
#   'www*fantic26*de (68.851) 99,8%'),
#  ('Striker Lux Stunt-Scooter Trick Tret Kinder Roller H=87cm 3,1kg Schwarz/Blau',
#   'EUR 189,95',
#   'jan_shop (22.256) 98,9%'),
#  ('LED Kinderroller Kinderscooter Cityroller Dreiradscooter Scooter Kinder Ricokids',
#   'EUR 37,99',
#   'arebos-shop (436.919) 97,9%'),
#  ('AREBOS Tretroller Kickscooter Cityroller Kinderroller | LED-Räder | klappbar',
#   'EUR 34,90',
#   'jan_shop (22.256) 98,9%'),
#  ('LED Kinderroller Kinderscooter Cityroller Dreiradscooter Scooter Kinder Ricokids',
#   'EUR 42,99',
#   'x-scooter (1.083) 97,9%'),
#  ('Megawheels E-Scooter Elektroroller Faltbar EScooter 250W 36V 25km Reichweite APP',
#   'EUR 299,00',
#   'demikay (64) 95,7%'),
#  ('Cityroller Cityroller Erwachsene Cityroller Kinder Kickscooter Tretroller DAUM®',
#   'EUR 69,90 bis EUR 74,90',
#   'daisyahome (11.625) 99,3%'),
#  ('Evoland Scooter Roller erwachsene Kinderroller Cityroller Tretroller Kickrolle',
#   'EUR 39,99',
#   'intheafterglow (1.937) 99%'),
#  ('Scooter Roller Kinderroller Kickscooter Cityroller Erwachsene Kinder Tretroller',
#   'EUR 39,99 bis EUR 50,99',
#   'wewillshopu (77.757) 98,1%'),
#  ('Blu:s XT600 E-Scooter 20 km/h, Straßenzulassung, 8" Vollgummireifen',
#   'EUR 249,99',
#   'hudora-de (337) 96,7%'),
#  ('HUDORA Scooter Big Wheel Roller Tretroller Cityroller Kickroller Ständer ocean',
#   'EUR 90,76',
#   'yyase-r (22.941) 99,3%'),
#  ('Kinderroller Cityroller Klappbar 205mm Rutschfest Scooter bis 100KG Funscooter',
#   'EUR 36,99',
#   'saturn (1.079.025) 97,6%'),
#  ('NINEBOT E2 D E-Scooter (8,1 Zoll, Black)',
#   'EUR 319,99',
#   'wmk-shop24 (315.099) 97,6%'),
#  ('KESSER® Stunt Scooter Cityroller Kickscooter Kinderroller Tretroller Funscooter',
#   'EUR 54,80 bis EUR 69,80',
#   'jan_shop (22.256) 98,9%'),
#  ('LED Kinderroller Kinderscooter Cityroller Dreiradscooter Scooter Kinder Ricokids',
#   'EUR 39,99',
#   'smh-shop24 (15.494) 99,7%'),
#  ('Stunt Scooter Cityroller Kickscooter Kinderroller Tretroller Funscooter 100mm',
#   'EUR 29,99 bis EUR 32,99',
#   'remoni-1619 (342) 98,6%'),
#  ('EVERCROSS EV10Kpro 10" E-Scooter mit Straßenzulassung(ABE),Vorne Motor 400W,36V',
#   'EUR 429,00',
#   'arebos-shop (436.919) 97,9%'),
#  ('AREBOS Tretroller Kickroller Cityroller Kinderroller Erwachsene Scooter Blau',
#   'EUR 39,90',
#   'wmk-shop24 (315.099) 97,6%'),
#  ('KESSER® Cityroller Scooter 205mm Roller Kinderroller Tretroller Kickroller Alu',
#   'EUR 69,80',
#   'vevendo (31.060) 100%'),
#  ('Stunt Scooter - Genius Pro - Robuster Kinder Scooter mit ABEC 9 Kugellager',
#   'EUR 74,99 bis EUR 89,99',
#   'remoni-1619 (342) 98,6%'),
#  ('RCB  EV10Kpro 10" E-Scooter mit Straßenzulassung(ABE),Vorne Motor 400W,36V',
#   'EUR 419,00',
#   'deguofff (5.948) 99,5%'),
#  ('Cityroller Erwachsene Klappbar Scooter Tretroller T-Style 200mm Räder+Handbremse',
#   'EUR 99,18',
#   'stylekiste (60.366) 99,1%'),
#  ('Cityroller Scooter Kinderroller Tretroller Aluminium Roller Kickroller klappbar',
#   'EUR 34,99',
#   'schnippi100802 (429) 84,2%'),
#  ('12" Tretroller black light Kinder Scooter Roller Kickroller Kinderroller 2. Wahl',
#   'EUR 29,99',
#   'demikay (64) 95,7%'),
#  ('Kinder Scooter Kinderroller Kinder Roller Kick Scooter Dreirad Tretroller DAUM®',
#   'EUR 39,90',
#   'tuning-chips (25) 100%'),
#  ('Xiaomi 1S, Pro 2 & Mi 3 E-Scooter Tuning Chip - 35km/h (für alle Versionen)',
#   'EUR 54,89',
#   'demikay (64) 95,7%'),
#  ('Kinder Scooter Kinderroller Kinder Roller Kick Scooter Dreirad LED klappbar DAUM',
#   'EUR 49,90',
#   'jan_shop (22.256) 98,9%'),
#  ('Stunt Scooter SOKE GO! Cityroller Kickscooter Kinderroller Tretroller Roller',
#   'EUR 49,90',
#   'remoni-1619 (342) 98,6%'),
#  ('EVERCROSS ES2 12" E-Scooter Kein ABE mit Sitz/Korb, 2-Pneumatikreifen,36V,10.4AH',
#   'EUR 438,00',
#   'cw-mobile-shop (336.351) 99,3%'),
#  ('Xiaomi Electric Scooter 3 Lite weiss E-Roller 20 km/h Reichweite. 20 km',
#   'EUR 318,49',
#   'intergo-de (341) 100%'),
#  ('Hoverboard Kinder 6,5 Zoll Bluetooth Elektro Scooter Balance Board ElektroRoller',
#   'EUR 99,99 bis EUR 119,99',
#   'geschenkwelten2024 (392) 98,8%'),
#  ('E-Scooter Tasche - Schwarz', 'EUR 17,99', 'calimpx (7.498) 99,2%'),
#  ('Kinderroller Tretroller Cityroller Geschenk Höhenverstellbar Scooter Klappbar',
#   'EUR 36,99',
#   'aosom_zuhause (99.141) 99%'),
#  ('HOMCOM Tretroller Kinderroller Scooter Cityroller Luftreifen verstellbar',
#   'EUR 64,90 bis EUR 74,90',
#   'buuws0 (3.242) 98,6%'),
#  ('LED Kinderroller Kinderscooter Dreiradscooter Faltbar Scooter Sitz Sets 5-in-1',
#   'EUR 36,19',
#   'wmk-shop24 (315.099) 97,6%'),
#  ('KESSER® Stunt Scooter Cityroller Kickscooter Kinderroller Tretroller Funscooter',
#   'EUR 64,80 bis EUR 99,80',
#   'wmk-shop24 (315.099) 97,6%')]

# %%
# Define column names for the DataFrame
columns = ['Title', 'Price', 'Seller']

# Create the DataFrame
df = pd.DataFrame(data_scooter, columns=columns)

# Print the DataFrame
df
# Out:
#                                                 Title  \
# 0                                        Shop on eBay
# 1   Urban E-Scooter mit Straßenzulassung Elektroro...
# 2   10 Zoll E-Scooter KickScooter mit Straßenzulas...
# 3   Elektroroller Mit Straßenzulassung Elektro Sco...
# 4   Chilli Pro Reaper Stunt-scooter H=84cm Trick P...
# ..                                                ...
# 78                         E-Scooter Tasche - Schwarz
# 79  Kinderroller Tretroller Cityroller Geschenk Hö...
# 80  HOMCOM Tretroller Kinderroller Scooter Cityrol...
# 81  LED Kinderroller Kinderscooter Dreiradscooter ...
# 82  KESSER® Stunt Scooter Cityroller Kickscooter K...
#
#                       Price                          Seller
# 0                    $20.00          mg-scooter (285) 97,6%
# 1                EUR 359,00          mg-scooter (285) 97,6%
# 2                EUR 359,00          mg-scooter (285) 97,6%
# 3                EUR 359,00  www*fantic26*de (68.851) 99,8%
# 4                EUR 179,00         weroll_tech (421) 98,9%
# ..                      ...                             ...
# 78                EUR 17,99           calimpx (7.498) 99,2%
# 79                EUR 36,99      aosom_zuhause (99.141) 99%
# 80  EUR 64,90 bis EUR 74,90            buuws0 (3.242) 98,6%
# 81                EUR 36,19      wmk-shop24 (315.099) 97,6%
# 82  EUR 64,80 bis EUR 99,80      wmk-shop24 (315.099) 97,6%
#
# [83 rows x 3 columns]
