# %%
import pandas as pd
import numpy as np
import time
import string
import re
import requests
from bs4 import BeautifulSoup
import selenium
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
# Out:
# C:\Users\Denish\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
#Aliexpress get all source code
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)
driver.get('https://www.aliexpress.com/category/100003109/women-clothing.html')
time.sleep(5)
soup=driver.page_source
driver.quit()
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

# Loading the webpage
driver.get('https://www.aliexpress.com/category/100003109/women-clothing.html')
time.sleep(5)

# Parsing the page source using BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')soup

# %%
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

# Loading the webpage
driver.get('https://www.aliexpress.com/category/100003109/women-clothing.html')
time.sleep(5)

# Get the page source
page_source = driver.page_source

# Parsing the page source using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Find all <div> elements with the specified class
div_elements = soup.find_all('div', class_="multi--dealContainer--T8SnTim")

# Loop through the found <div> elements
for div in div_elements:
    # Extract the data or perform operations on each <div> element
    print(div.text.strip())

# Quitting the WebDriver
driver.quit()

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ebay.de/sch/i.html?_from=R40&_trksid=p4432023.m570.l1313&_nkw=scooter&_sacat=0'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')
   
    # Find all the product titles
product_titles = soup.find_all('div',class_='s-item__title')
title =[]
for div in product_titles:
    # Extract the data or perform operations on each <div> element
    title.append(div.span.text.strip()) 
    

product_prices = soup.find_all('span', class_='s-item__price')
price =[]
for i in product_prices:
    price.append(i.text.strip()) 
    
    
product_feature = soup.find_all('span', class_='s-item__dynamic s-item__coupon')
feature = []
for i1 in product_feature:
    feature.append(i1.text.strip())    
    
seller_info =[]    
product_seller = soup.find_all('span', class_='s-item__seller-info-text')
for i2 in product_seller:
    seller_info.append(i2.text.strip())         
    
# sub_Title_info =[]    
# sub_Title_info = soup.find_all('span', class_='s-item__subtitle')
# for i3 in sub_Title_info:
#     sub_Title_info.append(i3.text.strip())

# %%
sub_Title_info =[]    
sub_Title_information = soup.find_all('div', class_='s-item__subtitle')
for i3 in sub_Title_information:
    sub_Title_info.append(i3.text.strip())

# %%
data_scooter = list(zip(title, price,seller_info,sub_Title_info))

# %%
# Define column names for the DataFrame
columns = ['Title', 'Price', 'Seller','sub_title']

# Create the DataFrame
df = pd.DataFrame(data_scooter, columns=columns)

# Print the DataFrame
df
# Out:
#                                                 Title  \
# 0                                        Shop on eBay
# 1   Urban E-Scooter mit Straßenzulassung Elektroro...
# 2   10 Zoll E-Scooter KickScooter mit Straßenzulas...
# 3   Elektroroller Mit Straßenzulassung Elektro Sco...
# 4   E Scooter Schloss Handschellenschloss für den ...
# ..                                                ...
# 78  Kinderroller Tretroller Cityroller Geschenk Hö...
# 79  Ninebot by Segway Elektro-Scooter KickScooter ...
# 80  HOMCOM Tretroller Kinderroller Scooter Cityrol...
# 81  Erwachsene Faltbarer Scooter mit Handbremse Ci...
# 82  City Scooter - Moonracer - klappbarer Kinder S...
#
#                       Price                              Seller  \
# 0                    $20.00              mg-scooter (286) 97,6%
# 1                EUR 359,00              mg-scooter (286) 97,6%
# 2                EUR 359,00              mg-scooter (286) 97,6%
# 3                EUR 359,00        cibirbaskinhandel (107) 100%
# 4                 EUR 66,99        evemotiongmbh (75.591) 97,1%
# ..                      ...                                 ...
# 78                EUR 36,99  euronics-maxi-media (62.234) 99,4%
# 79               EUR 815,50          aosom_zuhause (99.147) 99%
# 80                EUR 64,90                ktnparts (950) 99,5%
# 81                EUR 72,00               vevendo (31.060) 100%
# 82  EUR 34,99 bis EUR 49,99          wmk-shop24 (315.115) 97,6%
#
#                                             sub_title
# 0                                           Brand New
# 1    ✅ABE ✅10Zoll 🔥Sparen Sie €50,00 mit Code START24
# 2                               Brandneu | Gewerblich
# 3              🔥Sparen Sie EUR 50,00 mit Code START24
# 4                               Brandneu | Gewerblich
# ..                                                ...
# 78                              Brandneu | Gewerblich
# 79  Neu und unbenutzt, nur die Verpackung ist nich...
# 80                                  Brandneu | Privat
# 81  ⭐⭐⭐⭐⭐     ✔️3 Designs ✔️Deutsche Marke✔️LED✔️Q...
# 82                              Brandneu | Gewerblich
#
# [83 rows x 4 columns]

# %%
df["Seller"]
# Out:
# 0                 mg-scooter (286) 97,6%
# 1                 mg-scooter (286) 97,6%
# 2                 mg-scooter (286) 97,6%
# 3           cibirbaskinhandel (107) 100%
# 4           evemotiongmbh (75.591) 97,1%
#                      ...
# 78    euronics-maxi-media (62.234) 99,4%
# 79            aosom_zuhause (99.147) 99%
# 80                  ktnparts (950) 99,5%
# 81                 vevendo (31.060) 100%
# 82            wmk-shop24 (315.115) 97,6%
# Name: Seller, Length: 83, dtype: object

# %%
df[['Username', 'Feedback Score', 'Positive Feedback %']] = df['Seller'].str.split(r' \(|\) ', expand=True)

# %%
df.drop("Seller",axis=1,inplace = True)

# %%
df
# Out:
#                                                 Title  \
# 0                                        Shop on eBay
# 1   Urban E-Scooter mit Straßenzulassung Elektroro...
# 2   10 Zoll E-Scooter KickScooter mit Straßenzulas...
# 3   Elektroroller Mit Straßenzulassung Elektro Sco...
# 4   E Scooter Schloss Handschellenschloss für den ...
# ..                                                ...
# 78  Kinderroller Tretroller Cityroller Geschenk Hö...
# 79  Ninebot by Segway Elektro-Scooter KickScooter ...
# 80  HOMCOM Tretroller Kinderroller Scooter Cityrol...
# 81  Erwachsene Faltbarer Scooter mit Handbremse Ci...
# 82  City Scooter - Moonracer - klappbarer Kinder S...
#
#                       Price  \
# 0                    $20.00
# 1                EUR 359,00
# 2                EUR 359,00
# 3                EUR 359,00
# 4                 EUR 66,99
# ..                      ...
# 78                EUR 36,99
# 79               EUR 815,50
# 80                EUR 64,90
# 81                EUR 72,00
# 82  EUR 34,99 bis EUR 49,99
#
#                                             sub_title             Username  \
# 0                                           Brand New           mg-scooter
# 1    ✅ABE ✅10Zoll 🔥Sparen Sie €50,00 mit Code START24           mg-scooter
# 2                               Brandneu | Gewerblich           mg-scooter
# 3              🔥Sparen Sie EUR 50,00 mit Code START24    cibirbaskinhandel
# 4                               Brandneu | Gewerblich        evemotiongmbh
# ..                                                ...                  ...
# 78                              Brandneu | Gewerblich  euronics-maxi-media
# 79  Neu und unbenutzt, nur die Verpackung ist nich...        aosom_zuhause
# 80                                  Brandneu | Privat             ktnparts
# 81  ⭐⭐⭐⭐⭐     ✔️3 Designs ✔️Deutsche Marke✔️LED✔️Q...              vevendo
# 82                              Brandneu | Gewerblich           wmk-shop24
#
#    Feedback Score Positive Feedback %
# 0             286               97,6%
# 1             286               97,6%
# 2             286               97,6%
# 3             107                100%
# 4          75.591               97,1%
# ..            ...                 ...
# 78         62.234               99,4%
# 79         99.147                 99%
# 80            950               99,5%
# 81         31.060                100%
# 82        315.115               97,6%
#
# [83 rows x 6 columns]

# %%
url_cycle = "https://www.ebay.de/sch/i.html?_from=R40&_trksid=p2334524.m570.l2632&_nkw=fahrrad&_sacat=7294&_odkw=cycle&_osacat=0&_ipg=240"
response_cycle = requests.get(url_cycle)

# Check if the request was successful (status code 200)
# Parse the HTML content using BeautifulSoup
soup_cycle = BeautifulSoup(response_cycle.text, 'html.parser')
   
    # Find all the product titles
product_titles_cycle = soup_cycle.find_all('div',class_='s-item__title')
title_cycle =[]
for div in product_titles_cycle:
    # Extract the data or perform operations on each <div> element
    title_cycle.append(div.span.text.strip()) 
    

product_prices_cycle = soup_cycle.find_all('span', class_='s-item__price')
price_cycle =[]
for i in product_prices_cycle:
    price_cycle.append(i.text.strip()) 
    
    
# product_feature_cycle = soup_cycle.find_all('span', class_='s-item__dynamic s-item__coupon')
# feature_cycle = []
# for i1 in product_feature_cycle:
#     feature_cycle.append(i1.text.strip())    
    
seller_info_cycle =[]    
product_seller_cycle = soup_cycle.find_all('span', class_='s-item__seller-info-text')
for i2 in product_seller_cycle:
    seller_info_cycle.append(i2.text.strip())         
    
sub_Title_info_cycle =[]    
sub_Title_information_cycle = soup_cycle.find_all('div', class_='s-item__subtitle')
for i3 in sub_Title_information_cycle:
    sub_Title_info_cycle.append(i3.text.strip())

# %%
data_cycle = list(zip(title_cycle, price_cycle,seller_info_cycle,sub_Title_info_cycle))

# %%
# Define column names for the DataFrame
columns = ['Title_cycle', 'Price_cycle', 'Seller_cycle','sub_title_cycle']

# Create the DataFrame
df_cycle = pd.DataFrame(data_cycle, columns=columns)

# Print the DataFrame
df_cycle
# Out:
#                                            Title_cycle  \
# 0                                         Shop on eBay
# 1    DERUIZ E Bike E-Mountainbike27.5Zoll Pedelec C...
# 2     Vanraam Fahrrad Fun2Go Doppelt Duo *Top Zustand*
# 3    Fatbike 26 zoll ALUMINIUM FAHRRAD MTB  21 GANG...
# 4    City Bike Herren 700c Fahrrad 28 Fixed Bike St...
# ..                                                 ...
# 254  Neues AngebotComputer-St?nder Teil Computerhal...
# 255  Neues AngebotComputer-Ständer Teil Computerhal...
# 256  Neues Angebot Kinderfahrräder Fahrrad Fahren P...
# 257  Neues Angebot Lagerpedal Fahrradpedale Für Bes...
# 258  Neues AngebotFahrradpumpe Aufblasvorrichtung L...
#
#                  Price_cycle                        Seller_cycle  \
# 0                     $20.00              deruiz-ebike (78) 100%
# 1               EUR 1.499,00  rehaprodukte-shop2010 (3.976) 100%
# 2               EUR 4.550,00             bike-liga (8.391) 99,5%
# 3                 EUR 399,90             bike-liga (8.391) 99,5%
# 4                 EUR 299,90               hadjt-109739 (20) 50%
# ..                       ...                                 ...
# 254                EUR 31,59             snapomall (1.472) 99,1%
# 255                EUR 25,22             dramaastore (3.731) 99%
# 256   EUR 9,39 bis EUR 22,51               ohohmygod (2.905) 97%
# 257  EUR 10,13 bis EUR 24,26              ryxjanuary (597) 98,7%
# 258                EUR 10,95   cartrend_mts_group (61.381) 99,6%
#
#                                        sub_title_cycle
# 0                                            Brand New
# 1    250W 55Nm Motor✅Maximal150km✅Shimano 8G✅2Jahr ...
# 2                                Brandneu | Gewerblich
# 3                               Gebraucht | Gewerblich
# 4                                Brandneu | Gewerblich
# ..                                                 ...
# 254                              Brandneu | Gewerblich
# 255                              Brandneu | Gewerblich
# 256                              Brandneu | Gewerblich
# 257                              Brandneu | Gewerblich
# 258                  Brandneu | Gewerblich | Markenlos
#
# [259 rows x 4 columns]

# %%
df_cycle[['Username', 'Feedback Score', 'Positive Feedback %']] = df_cycle["Seller_cycle"].str.split(r"\(|\)",expand = True)

# %%
df_cycle.drop("Seller_cycle",axis = 1,inplace = True)

# %%
df.drop("sub_title",axis =1,inplace =True)

# %%
df.columns
# Out:
# Index(['Title', 'Price', 'Username', 'Feedback Score', 'Positive Feedback %'], dtype='object')

# %%
df_cycle.drop('sub_title_cycle',axis=1,inplace =True)

# %%
df_cycle.rename(columns = {"Title_cycle":"Title","Price_cycle":"Price"},inplace = True)

# %%
df_cycle
# Out:
#                                                  Title  \
# 0                                         Shop on eBay
# 1    DERUIZ E Bike E-Mountainbike27.5Zoll Pedelec C...
# 2     Vanraam Fahrrad Fun2Go Doppelt Duo *Top Zustand*
# 3    Fatbike 26 zoll ALUMINIUM FAHRRAD MTB  21 GANG...
# 4    City Bike Herren 700c Fahrrad 28 Fixed Bike St...
# ..                                                 ...
# 254  Neues AngebotComputer-St?nder Teil Computerhal...
# 255  Neues AngebotComputer-Ständer Teil Computerhal...
# 256  Neues Angebot Kinderfahrräder Fahrrad Fahren P...
# 257  Neues Angebot Lagerpedal Fahrradpedale Für Bes...
# 258  Neues AngebotFahrradpumpe Aufblasvorrichtung L...
#
#                        Price                Username Feedback Score  \
# 0                     $20.00           deruiz-ebike              78
# 1               EUR 1.499,00  rehaprodukte-shop2010           3.976
# 2               EUR 4.550,00              bike-liga           8.391
# 3                 EUR 399,90              bike-liga           8.391
# 4                 EUR 299,90           hadjt-109739              20
# ..                       ...                     ...            ...
# 254                EUR 31,59              snapomall           1.472
# 255                EUR 25,22            dramaastore           3.731
# 256   EUR 9,39 bis EUR 22,51              ohohmygod           2.905
# 257  EUR 10,13 bis EUR 24,26             ryxjanuary             597
# 258                EUR 10,95     cartrend_mts_group          61.381
#
#     Positive Feedback %
# 0                  100%
# 1                  100%
# 2                 99,5%
# 3                 99,5%
# 4                   50%
# ..                  ...
# 254               99,1%
# 255                 99%
# 256                 97%
# 257               98,7%
# 258               99,6%
#
# [259 rows x 5 columns]

# %%
new_Df = pd.concat([df,df_cycle],axis =0)

# %%
new_Df["Positive Feedback %"] = new_Df["Positive Feedback %"].replace("%","")

# %%
from sklearn.linear_model import LinearRegression

# %%
new_Df["Positive Feedback %"] = new_Df["Positive Feedback %"].str.replace(',', '').str.rstrip('%').astype(float) / 100

# %%
new_Df["Positive Feedback %"]
# Out:
# 0      9.76
# 1      9.76
# 2      9.76
# 3      1.00
# 4      9.71
#        ...
# 254    9.91
# 255    0.99
# 256    0.97
# 257    9.87
# 258    9.96
# Name: Positive Feedback %, Length: 342, dtype: float64

# %%
new_Df["Feedback Score"]
# Out:
# 0        286.0
# 1        286.0
# 2        286.0
# 3        107.0
# 4      75591.0
#         ...
# 254     1472.0
# 255     3731.0
# 256     2905.0
# 257      597.0
# 258    61381.0
# Name: Feedback Score, Length: 342, dtype: float64

# %%
new_Df["Feedback Score"]
# Out:
# 0        286.0
# 1        286.0
# 2        286.0
# 3        107.0
# 4      75591.0
#         ...
# 254     1472.0
# 255     3731.0
# 256     2905.0
# 257      597.0
# 258    61381.0
# Name: Feedback Score, Length: 342, dtype: float64

# %%
new_Df
# Out:
#                                                  Title  \
# 0                                         Shop on eBay
# 1    Urban E-Scooter mit Straßenzulassung Elektroro...
# 2    10 Zoll E-Scooter KickScooter mit Straßenzulas...
# 3    Elektroroller Mit Straßenzulassung Elektro Sco...
# 4    E Scooter Schloss Handschellenschloss für den ...
# ..                                                 ...
# 254  Neues AngebotComputer-St?nder Teil Computerhal...
# 255  Neues AngebotComputer-Ständer Teil Computerhal...
# 256  Neues Angebot Kinderfahrräder Fahrrad Fahren P...
# 257  Neues Angebot Lagerpedal Fahrradpedale Für Bes...
# 258  Neues AngebotFahrradpumpe Aufblasvorrichtung L...
#
#                        Price             Username  Feedback Score  \
# 0                     $20.00           mg-scooter           286.0
# 1                 EUR 359,00           mg-scooter           286.0
# 2                 EUR 359,00           mg-scooter           286.0
# 3                 EUR 359,00    cibirbaskinhandel           107.0
# 4                  EUR 66,99        evemotiongmbh         75591.0
# ..                       ...                  ...             ...
# 254                EUR 31,59           snapomall           1472.0
# 255                EUR 25,22         dramaastore           3731.0
# 256   EUR 9,39 bis EUR 22,51           ohohmygod           2905.0
# 257  EUR 10,13 bis EUR 24,26          ryxjanuary            597.0
# 258                EUR 10,95  cartrend_mts_group          61381.0
#
#      Positive Feedback %
# 0                   9.76
# 1                   9.76
# 2                   9.76
# 3                   1.00
# 4                   9.71
# ..                   ...
# 254                 9.91
# 255                 0.99
# 256                 0.97
# 257                 9.87
# 258                 9.96
#
# [342 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
LR_data = new_Df[["Feedback Score","Positive Feedback %"]]

# %%
pd.set_option('display.max_rows', None)

# %%
LR_data
# Out:
#      Feedback Score  Positive Feedback %
# 0             286.0                 9.76
# 1             286.0                 9.76
# 2             286.0                 9.76
# 3             107.0                 1.00
# 4           75591.0                 9.71
# 5             283.0                 9.86
# 6             421.0                 9.89
# 7           32581.0                 9.99
# 8           22260.0                 9.89
